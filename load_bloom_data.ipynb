# %%
import os
import pandas as pd
import sqlalchemy

# %%
os.chdir("/home/michal/Downloads")

# %%
os.listdir()
# Out:
# ['firefox-57.0.2.tar.bz2', 'Kwotowania bloomberg.csv']

# %%
data = pd.read_csv("Kwotowania bloomberg.csv", sep = ';', decimal = ',')

# %%
data.columns
# Out:
# Index(['INSTRUMENT', 'Date', 'OPEN', 'HIGH', 'LOW', 'CLOSE'], dtype='object')

# %%
data.columns = ['INSTRUMENT', 'datetime', 'open', 'high', 'low', 'close']

# %%
data['datetime'] = pd.to_datetime(data['datetime'], format = "%Y-%m-%d %H:%M")

# %%
gbpusd = data[data['INSTRUMENT'] == 'GBPUSD']

# %%
gbpusd = gbpusd.drop('INSTRUMENT', 1)

# %%
gbpusd['volume'] = 0
gbpusd['source'] = 'bloomberg'
gbpusd
# Out:
#                  datetime     open     high      low    close  volume  \
# 23516 2017-11-13 09:01:00  1.30965  1.30975  1.30945  1.30945       0
# 23517 2017-11-13 09:02:00  1.30945  1.30965  1.30935  1.30955       0
# 23518 2017-11-13 09:03:00  1.30955  1.30965  1.30945  1.30945       0
# 23519 2017-11-13 09:04:00  1.30945  1.31005  1.30945  1.30980       0
# 23520 2017-11-13 09:05:00  1.30980  1.31005  1.30980  1.31000       0
# 23521 2017-11-13 09:06:00  1.31000  1.31010  1.30975  1.31005       0
# 23522 2017-11-13 09:07:00  1.31005  1.31015  1.30985  1.31005       0
# 23523 2017-11-13 09:08:00  1.31005  1.31010  1.30995  1.31000       0
# 23524 2017-11-13 09:09:00  1.31000  1.31020  1.30995  1.31010       0
# 23525 2017-11-13 09:10:00  1.31010  1.31030  1.30995  1.31005       0
# 23526 2017-11-13 09:11:00  1.31005  1.31010  1.30965  1.30965       0
# 23527 2017-11-13 09:12:00  1.30965  1.30965  1.30910  1.30950       0
# ...

# %%
con = sqlalchemy.create_engine('mysql://root:nasdaq93@127.0.0.1/hedge_fund') 
gbpusd.to_sql('gbpusd', con, if_exists = 'append')
# Out:
# /home/michal/anaconda3/lib/python3.6/site-packages/sqlalchemy/dialects/mysql/base.py:1569: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   cursor.execute('SELECT @@tx_isolation')

# %%
data = data[data['INSTRUMENT'] == 'EURUSD']
data = data.drop('INSTRUMENT', 1)
data['volume'] = 0
data['source'] = 'bloomberg'
data.to_sql('eurusd', con, if_exists = 'append')

# %%
data0 = data[data['INSTRUMENT'] == 'EURPLN']
data0 = data0.drop('INSTRUMENT', 1)
data0['volume'] = 0
data0['source'] = 'bloomberg'
data0.to_sql('eurpln', con, if_exists = 'append')

# %%
data0 = data[data['INSTRUMENT'] == 'AUDUSD']
data0 = data0.drop('INSTRUMENT', 1)
data0['volume'] = 0
data0['source'] = 'bloomberg'
data0.to_sql('audusd', con, if_exists = 'append')

# %%
data0 = data[data['INSTRUMENT'] == 'USDJPY']
data0 = data0.drop('INSTRUMENT', 1)
data0['volume'] = 0
data0['source'] = 'bloomberg'
data0.to_sql('usdjpy', con, if_exists = 'append')
